# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/rafal/Desktop/DS/Merceri price/train.tsv", sep = '\t')

# %%
data.head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# ...

# %%
pv = pd.pivot_table(data, values = ['price'],index = ['brand_name'], aggfunc = ['count', np.mean, np.median])

# %%
pv.columns = pv.columns.get_level_values(0)

# %%
pv.sort_values(by = ['count'], ascending = False)
# Out:
#                       count        mean  median
# brand_name
# PINK                  54088   26.341314    20.0
# Nike                  54043   30.760265    22.0
# Victoria's Secret     48036   23.214287    19.0
# LuLaRoe               31024   33.667967    29.0
# Apple                 17322   73.268618    22.0
# FOREVER 21            15186   12.929935    12.0
# Nintendo              15007   34.672619    20.0
# Lululemon             14558   47.096717    39.0
# Michael Kors          13928   62.254775    49.0
# American Eagle        13254   15.960955    14.0
# Rae Dunn              12305   37.170581    30.0
# Sephora               12172   21.820613    16.0
# Coach                 10463   41.142550    31.0
# Disney                10360   17.146670    13.0
# Bath & Body Works     10354   17.905737    14.0
# Adidas                10202   43.127328    25.0
# Funko                  9237   29.054888    20.0
# Under Armour           8461   19.367923    16.0
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of          train_id                                     name  item_condition_id  \
# 0               0      MLB Cincinnati Reds T Shirt Size XL                  3
# 1               1         Razer BlackWidow Chroma Keyboard                  3
# 2               2                           AVA-VIV Blouse                  1
# 3               3                    Leather Horse Statues                  1
# 4               4                     24K GOLD plated rose                  1
# 5               5         Bundled items requested for Ruie                  3
# 6               6       Acacia pacific tides santorini top                  3
# 7               7     Girls cheer and tumbling bundle of 7                  3
# 8               8                    Girls Nike Pro shorts                  3
# 9               9   Porcelain clown doll checker pants VTG                  3
# 10             10                          Smashbox primer                  2
# ...
